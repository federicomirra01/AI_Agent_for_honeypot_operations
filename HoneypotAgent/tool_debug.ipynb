# %%
import json

# %%
def getNetworkStatus(file_path="../logsSSH/tshark_pcap/ssh_traffic.json") -> dict:
    """
    Retrieve current network activity from parsed logs.
    
    Parameters:
    - file_path (str): Path to the JSON file containing tshark output
    
    Returns:
    - dict: network activity
    """
    
    
    try:
        # Load the JSON data from tshark output
        with open(file_path, 'r') as file:
            raw_data = json.load(file)
        
        
    except Exception as e:
        return {
            "error": "Processing error",
            "details": str(e)
        }
    return raw_data

getNetworkStatus()
# Out:
# [{'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.094397149 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.094433299 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.094447294 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.094610105 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.094642491 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.101536839 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.101558966 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.102445335 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.102461739 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.103699479 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.144317571 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.144337285 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.150250521 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.150560753 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.191247842 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.191317842 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.191327972 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.191410706 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.191644199 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.193176507 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.193507359 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.193524826 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.193871068 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45498']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.193878969 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45498'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424696172 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424706853 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424719401 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424726436 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424727516 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424730887 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424735735 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424742583 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424753134 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424781331 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424786491 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424793619 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424801977 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424816168 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424818951 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424821396 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424826576 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424829807 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424867806 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424870433 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424872686 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424876987 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424877577 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424922841 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424929259 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45558']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424934849 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424938053 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424946180 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424959305 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424971863 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45572']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.424979630 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425003021 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425006777 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425011171 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425011897 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45580']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425017015 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425044148 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45586'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425046015 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425048714 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45586']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425050321 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425053436 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45586'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425082522 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425085428 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45592']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425085442 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425088750 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425090973 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425099816 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45600'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425104639 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45600']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425105240 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425109013 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45600'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425115445 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45604'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425119387 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45604']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425120111 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425122649 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45604'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425131785 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.425134655 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45558']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.429569143 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.429580323 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.430381558 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.430387375 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.431096691 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.431108906 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.431824223 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.431833981 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.434257382 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.434272976 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.435110130 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.435121551 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.435792241 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.435809875 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.437144361 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.437164970 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.437685266 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.437696511 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438030303 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438043868 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438538590 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438549707 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438554918 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.438570965 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439237349 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45620'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439258422 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45620']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439270920 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45620'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439270388 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45630'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439283616 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45586'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439287890 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45630']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439288109 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45558']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439288764 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45586']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439288472 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439291626 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439298038 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439298930 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45630'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439300002 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45580']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439300066 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45592']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439301758 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45586']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439308716 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45586']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439310285 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45586'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439318586 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45600'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439322473 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439324845 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45600']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439327358 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45586']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439357783 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45604'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439360034 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439373949 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45604']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439412710 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439435684 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439437506 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45630'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439444747 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45620'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439446387 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45630']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439451719 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45620']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439519554 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439529934 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45572']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439839300 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439841732 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439863406 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.439954048 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440146355 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440150658 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440150995 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440293235 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440460037 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45558']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440554381 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.440705217 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.442899697 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45572']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.442913659 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443287790 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45604']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443300314 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45604'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443311319 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45604']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443351669 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45620']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443355701 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45620'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443361514 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45620']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443713689 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.443931119 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45572']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.444267811 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45572'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.444500263 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45592']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.444516941 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445228641 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445358115 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45580']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445379667 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445399714 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45592']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445610103 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45592'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.445898862 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.446324651 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45580']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.446571501 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45580'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.447201943 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45558']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.447487843 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45558'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.448302415 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45630']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.448312967 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45630'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.448924185 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45630'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.448988621 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45600']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.449015214 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45600'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.449144060 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
# ...
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531166457 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531170730 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531228280 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531242363 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531244724 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531274554 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531439985 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531441424 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531800178 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531902068 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531975104 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.531986132 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532011453 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532017096 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532029005 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532042022 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532159960 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532182704 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532280500 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532385639 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532568834 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.532699619 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.533274989 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.533444193 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.533461276 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.533581129 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.534069174 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.534109122 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.534169068 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.534305205 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.538580491 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.539323186 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.539644406 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540139730 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540151439 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45526']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540166281 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45526'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540296133 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540710494 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45504']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540721377 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45504'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.540903760 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541195796 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541255851 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541629118 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541664787 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45516']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541688179 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45516'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541747405 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.541841320 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.542323152 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45502']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.542338251 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45502'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.542676495 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.542714911 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.542733374 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543100679 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45512']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543114309 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45512'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543290443 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45546']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543303097 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45546'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543306259 CEST'],
#     'ip.src': ['172.17.0.2'],
#     'tcp.srcport': ['2222'],
#     'ip.dst': ['172.17.0.1'],
#     'tcp.dstport': ['45530']}}},
#  {'_index': 'packets-2025-04-22',
#   '_type': 'doc',
#   '_score': None,
#   '_source': {'layers': {'frame.time': ['Apr 22, 2025 10:24:17.543316955 CEST'],
#     'ip.src': ['172.17.0.1'],
#     'tcp.srcport': ['45530'],
#     'ip.dst': ['172.17.0.2'],
#     'tcp.dstport': ['2222']}}}]
